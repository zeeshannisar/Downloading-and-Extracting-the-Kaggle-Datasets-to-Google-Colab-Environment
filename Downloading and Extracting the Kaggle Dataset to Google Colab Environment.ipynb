# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### **Step# 1**
#
# Create a Kaggle account at https://www.kaggle.com/
#
# Click on your username ![]('/content/drive/')

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle

# %%
from google.colab import files
files.upload()

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets list
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                         title                                                size  lastUpdated          downloadCount
# ----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# unanimad/dataisbeautiful                                    Reddit - Data is Beautiful                           11MB  2020-03-21 22:28:28            575
# allen-institute-for-ai/CORD-19-research-challenge           COVID-19 Open Research Dataset Challenge (CORD-19)  646MB  2020-03-20 23:31:34          24815
# rubenssjr/brasilian-houses-to-rent                          brazilian_houses_to_rent                            117KB  2020-03-15 01:12:22            571
# sudalairajkumar/novel-corona-virus-2019-dataset             Novel Corona Virus 2019 Dataset                     389KB  2020-03-23 05:12:36          72591
# kimjihoo/coronavirusdataset                                 Data Science for COVID-19 (DS4C)                      3MB  2020-03-22 04:17:54          19466
# jessemostipak/hotel-booking-demand                          Hotel booking demand                                  1MB  2020-02-13 01:27:20           9906
# shivamb/real-or-fake-fake-jobposting-prediction             [Real or Fake] Fake JobPosting Prediction            16MB  2020-02-29 08:23:34           2003
# brunotly/foreign-exchange-rates-per-dollar-20002019         Foreign Exchange Rates 2000-2019                      1MB  2020-03-03 17:43:07           1548
# timoboz/data-science-cheat-sheets                           Data Science Cheat Sheets                           596MB  2020-02-04 19:42:27           6045
# imdevskp/ebola-outbreak-20142016-complete-dataset           Ebola 2014-2016 Outbreak Complete Dataset           101KB  2020-02-26 14:36:31           1817
# imdevskp/sars-outbreak-2003-complete-dataset                SARS 2003 Outbreak Complete Dataset                  10KB  2020-02-26 10:25:22           1867
# tunguz/big-five-personality-test                            Big Five Personality Test                           159MB  2020-02-17 15:59:37           3029
# brendaso/2019-coronavirus-dataset-01212020-01262020         2019 Coronavirus dataset (January - February 2020)   53KB  2020-02-06 18:09:28           9496
# jamzing/sars-coronavirus-accession                          SARS CORONAVIRUS ACCESSION                            2MB  2020-02-18 15:49:34           2525
# paultimothymooney/coronavirus-genome-sequence               Coronavirus Genome Sequence                           9MB  2020-02-29 00:25:13            522
# timoboz/tesla-stock-data-from-2010-to-2020                  Tesla stock data from 2010 to 2020                   46KB  2020-02-04 17:15:32           2932
# prakrutchauhan/indian-candidates-for-general-election-2019  Indian Candidates for General Election 2019         133KB  2020-03-03 07:01:53            954
# timoboz/python-data-science-handbook                        Python Data Science Handbook                         15MB  2020-02-04 18:27:14           1429
# gpiosenka/100-bird-species                                  150 Bird Species                                    946MB  2020-03-15 23:17:43            952
# timoboz/google-trends-data                                  Google Trends Data                                    1MB  2020-02-04 17:31:10           2983

# %%
# !kaggle datasets download -d jessicali9530/celeba-dataset -p '/content/drive/My Drive/GitHub Repositories/Generative Models Papers with Implementation in Keras/Autoencoders/datasets/'
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading celeba-dataset.zip to /content/drive/My Drive/GitHub Repositories/Generative Models Papers with Implementation in Keras/Autoencoders/datasets
#  99% 1.32G/1.33G [00:07<00:00, 187MB/s]
# 100% 1.33G/1.33G [00:08<00:00, 178MB/s]

# %%
# !ls '/content/drive/My Drive/GitHub Repositories/Generative Models Papers with Implementation in Keras/Autoencoders/datasets'
# Out:
# celeba-dataset.zip

# %%
import os
from tqdm.notebook import tqdm
dataPath = '/content/drive/My Drive/GitHub Repositories/Generative Models Papers with Implementation in Keras/Autoencoders/datasets/celeba-dataset.zip'
extractionPath = '/content/drive/My Drive/GitHub Repositories/Generative Models Papers with Implementation in Keras/Autoencoders/datasets/'
#Unzip the dataset downloaded from kaggle
from zipfile import ZipFile
with ZipFile(dataPath, 'r') as zf:
  for member in tqdm(zf.infolist(), desc='Extracting'):
    try:
      # Extract all the contents of zip file in the data directory
      zf.extract(member, extractionPath)
    except zipfile.error as e:
      pass
# Out:
# HBox(children=(IntProgress(value=0, description='Extracting', max=202603, style=ProgressStyle(description_widt…
